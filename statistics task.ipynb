# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("house_price.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.price_per_sqft.mean()
# Out:
# 7920.336742424242

# %%
df.price_per_sqft.median()
# Out:
# 5438.0

# %%
df[df.price_per_sqft.isna()]
# Out:
# Empty DataFrame
# Columns: [location, size, total_sqft, bath, price, bhk, price_per_sqft]
# Index: []

# %%
df.price_per_sqft.quantile([0.05,0.15,0.25,0.5,0.75,0.85,0.9,0.95])
# Out:
# 0.05     3107.85
# 0.15     3800.00
# 0.25     4267.00
# 0.50     5438.00
# 0.75     7317.00
# 0.85     9333.90
# 0.90    11666.00
# 0.95    15312.10
# Name: price_per_sqft, dtype: float64

# %%
df.price_per_sqft.quantile(0.8)
# Out:
# 8019.200000000001

# %%
df[df.price_per_sqft>df.price_per_sqft.quantile(0.85)]
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 11           Whitefield  4 Bedroom      2785.0   5.0  295.0    4
# 18                other      3 BHK      2770.0   4.0  290.0    3
# 22          Thanisandra  4 Bedroom      2800.0   5.0  380.0    4
# ...                 ...        ...         ...   ...    ...  ...
# 13185          Hulimavu      1 BHK       500.0   1.0  220.0    1
# 13186             other  4 Bedroom      1200.0   5.0  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
# 13196             other      4 BHK      3600.0   5.0  400.0    4
# 13198   Padmanabhanagar      4 BHK      4689.0   4.0  488.0    4
#
#        price_per_sqft
# 7               18181
# 9               36274
# 11              10592
# 18              10469
# 22              13571
# ...               ...
# ...

# %%
df_no_outlier = df[df.price_per_sqft<df.price_per_sqft.quantile(0.85)]
df_no_outlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13193               Uttarahalli      3 BHK      1345.0   2.0   57.00    3
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## IQR

# %%
q1 = df.price_per_sqft.quantile(0.25)
q1
# Out:
# 4267.0

# %%
q3 = df.price_per_sqft.quantile(0.75)
q3
# Out:
# 7317.0

# %%
df.price_per_sqft.quantile(0.5)
# Out:
# 5438.0

# %%
df.price_per_sqft.median()
# Out:
# 5438.0

# %%
iqr = q3-q1

# %%
iqr
# Out:
# 3050.0

# %%
lower=q1-1.5*iqr
upper=q3+1.5*iqr

lower,upper
# Out:
# (-308.0, 11892.0)

# %%
#outliers
df[(df.price_per_sqft<-308) | (df.price_per_sqft>11892)]
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 22          Thanisandra  4 Bedroom      2800.0   5.0  380.0    4
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 48             KR Puram  2 Bedroom       800.0   1.0  130.0    2
# ...                 ...        ...         ...   ...    ...  ...
# 13142             other      2 BHK      1140.0   1.0  185.0    2
# 13157             other  7 Bedroom      1400.0   7.0  218.0    7
# 13185          Hulimavu      1 BHK       500.0   1.0  220.0    1
# 13186             other  4 Bedroom      1200.0   5.0  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 7               18181
# 9               36274
# 22              13571
# 45              33333
# 48              16250
# ...               ...
# ...

# %%
df_without_outlier_iqr = df[(df.price_per_sqft>-308) & (df.price_per_sqft<11892)]

# %%
df_without_outlier_iqr
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## Normal Distribution

# %%
m = df.price_per_sqft.mean()
m
# Out:
# 7920.336742424242

# %%
s = df.price_per_sqft.std()
s
# Out:
# 106727.16032810867

# %%
m-3*s #-3sigma
# Out:
# -312261.14424190175

# %%
m+3*s #+3sigma
# Out:
# 328101.8177267502

# %%
df_nooutliers_ND=df[(df.price_per_sqft>-312261) & (df.price_per_sqft<328101)]
df_nooutliers_ND
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %% [markdown]
# ## Z Score

# %%
df["zscore"] = (df.price_per_sqft-m)/s #z = x-mean/std
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# ...

# %%
df_nooutlier_zscore=df[(df.zscore>-3) & (df.zscore<3)]
df_nooutlier_zscore
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft    zscore
# 0                3699 -0.039553
# ...

# %% [markdown]
# # Histplot

# %%
#sns.histplot(data=df,x=df.price_per_sqft,kde=True)
matplotlib.rcParams["figure.figsize"] = (20,10)
plt.hist(df.price_per_sqft,rwidth=0.8)
# Out:
# (array([1.3198e+04, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([2.67000000e+02, 1.20024030e+06, 2.40021360e+06, 3.60018690e+06,
#         4.80016020e+06, 6.00013350e+06, 7.20010680e+06, 8.40008010e+06,
#         9.60005340e+06, 1.08000267e+07, 1.20000000e+07]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Box Plot

# %%
plt.boxplot(df.total_sqft)
plt.show()

# %%
plt.boxplot(df.bath)
plt.show()

# %%
plt.boxplot(df.price)
plt.show()

# %%
plt.boxplot(df.bhk)
plt.show()

# %% [markdown]
# ## Correlation

# %%
df1=df.drop(["zscore","location","size"],axis=1)
df1
# Out:
#        total_sqft  bath   price  bhk  price_per_sqft
# 0          1056.0   2.0   39.07    2            3699
# 1          2600.0   5.0  120.00    4            4615
# 2          1440.0   2.0   62.00    3            4305
# 3          1521.0   3.0   95.00    3            6245
# 4          1200.0   2.0   51.00    2            4250
# ...           ...   ...     ...  ...             ...
# 13195      3453.0   4.0  231.00    5            6689
# 13196      3600.0   5.0  400.00    4           11111
# 13197      1141.0   2.0   60.00    2            5258
# 13198      4689.0   4.0  488.00    4           10407
# 13199       550.0   1.0   17.00    1            3090
#
# [13200 rows x 5 columns]

# %%
corr1 = df1.corr()
corr1
# Out:
#                 total_sqft      bath     price       bhk  price_per_sqft
# total_sqft        1.000000  0.392743  0.574330  0.346013       -0.008267
# bath              0.392743  1.000000  0.455998  0.897951        0.030883
# price             0.574330  0.455998  1.000000  0.396883        0.028387
# bhk               0.346013  0.897951  0.396883  1.000000        0.030955
# price_per_sqft   -0.008267  0.030883  0.028387  0.030955        1.000000

# %%
sns.heatmap(corr1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Scatter Plot

# %%
sns.pairplot(df1, diag_kind='scatter')

# Show plot
plt.show()
